# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/juandavidcaicedocastro/Dropbox/BERKELEY/07_COURSES/06_spring_2020/01_CP255/Data cleaning'

# %%
path = '/Users/juandavidcaicedocastro/Dropbox/BERKELEY/17_PhD/02_Data/02_Encuestas de movilidad/03_2019/BD EODH2019 FINAL v14022020/Archivos CSV/'

# %%
households = pd.read_csv(path + 'HogaresEODH2019.csv',sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-693eb2b89890> in <module>
# ----> 1 households = pd.read_csv(path + 'HogaresEODH2019.csv',sep=';')
#
# ~/anaconda3/envs/tm/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
households
# Out:
#       Id_Hogar  Estado  p1_encuestador  p2_supervisor  p3_nro_mapa  \
# 0        10003       2            9068            NaN          950
# 1        18369       2            9858            NaN           20
# 2        20163       1            9544            NaN         2790
# 3         2913       1            8909            NaN         2781
# 4        14581       1            9447            NaN           63
# ...        ...     ...             ...            ...          ...
# 21823    33537       1           10619            NaN         4093
# 21824     2529       1            9235            NaN           16
# 21825     2530       1            9235            NaN           16
# 21826    32373       1           10602            NaN           15
# 21827    34340       1           10770            NaN         4091
#
#        p4_nro_manzana     Utam  Sector  Seccion  Manzana  ...  \
# 0        1.100119e+13    UTAM2    9124        1       17  ...
# ...
